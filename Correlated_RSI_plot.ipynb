# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.dates as mdates
import numpy as np
import datetime as dt

# %%
month = {"Jan" : "01" , "Feb": "02" , "Mar" : "03","Apr": "04","May":"05","Jun" : "06","Jul":"07","Aug":"08","Sep":"09","Oct":"10","Nov":"11","Dec":"12"}
for i in rsi.loc[:,"dates"]:
  prev_i = i
  s = slice(3,6,1)
  i = i.replace(i[s], month[i[s]] )
  i = i.replace("-","/")
  s = slice(6,8,1)
  s1 = slice(6)
  i = i[s1]+"20"+i[s]
  rsi['dates'] = rsi['dates'].replace(prev_i,i)

fig, axs = plt.subplots(2,1,figsize=(16,9), gridspec_kw={'height_ratios': [2, 1]})

ax2 = axs[0]
ax2.plot(dates,comapny_A_data,'r',dates,company_B_data,'g')
ax2.xaxis.set_major_locator(MaxNLocator(prune='lower'))
ax2.set_title('Stock price for correlated pair')
ax2.legend(["Asian Paints", "Hindunilvr"], loc ="upper right")

ax2.set_ylabel('Price')

ax1 = axs[1]
ax1.plot(dates,y1,'#000000',dates,y2,'#000000',dates,rsi_values,'#069AF3')
plt.gca().xaxis.set_major_locator(MaxNLocator(prune='lower'))
ax1.set_xlabel('dates')
ax1.set_ylabel('RSI Values')
ax1.set_title('Relative Strength Index')
ax1.set_ylim([0,100])
ax1.set_yticks([30,70])

# %%
ax2.plot(dates,comapny_A_data,'r',dates,company_B_data,'g')
plt.gca().xaxis.set_major_locator(MaxNLocator(prune='lower'))

# %%
rsi = pd.read_csv('/content/TECHM_ICICIBANK_with_rsi.csv')
comapny_A_data = rsi['company A']
company_B_data = rsi['company B'] 
dates = rsi["dates"]
comapny_A_data = comapny_A_data.tolist()
company_B_data = company_B_data.tolist()
rsi_values = rsi['rsi'] 
# values = values.tolist()
rsi_values = rsi_values.tolist()

fig, axs = plt.subplots(2,1,figsize=(16,9), gridspec_kw={'height_ratios': [2, 1]})

ax2 = axs[0]
ax2.plot(dates,comapny_A_data,'r',dates,company_B_data,'g')
ax2.xaxis.set_major_locator(MaxNLocator(prune='lower'))
ax2.set_title('Stock price for correlated pair')
ax2.legend(["TECHM", "ICICIBANK"], loc ="upper right")

ax2.set_ylabel('Price')

ax1 = axs[1]
ax1.plot(dates,y1,'#000000',dates,y2,'#000000',dates,rsi_values,'#069AF3')
plt.gca().xaxis.set_major_locator(MaxNLocator(prune='lower'))
ax1.set_xlabel('dates')
ax1.set_ylabel('RSI Values')
ax1.set_title('Relative Strength Index')
ax1.set_ylim([0,100])
ax1.set_yticks([30,70])

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
